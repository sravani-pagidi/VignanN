# %% [markdown]
# <a href="https://colab.research.google.com/github/sravani-pagidi/VignanN/blob/main/Regularization_multiclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 78ms/step - loss: 7.3071 - categorical_accuracy: 0.3843 - val_loss: 3.8569 - val_categorical_accuracy: 0.5362
# Epoch 2/25
# 16/16 [==============================] - 1s 57ms/step - loss: 3.4620 - categorical_accuracy: 0.5491 - val_loss: 3.1603 - val_categorical_accuracy: 0.5825
# Epoch 3/25
# 16/16 [==============================] - 1s 57ms/step - loss: 3.0612 - categorical_accuracy: 0.5968 - val_loss: 2.8932 - val_categorical_accuracy: 0.6400
# Epoch 4/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.8464 - categorical_accuracy: 0.6351 - val_loss: 2.7172 - val_categorical_accuracy: 0.6500
# Epoch 5/25
# 16/16 [==============================] - 1s 78ms/step - loss: 2.7013 - categorical_accuracy: 0.6519 - val_loss: 2.5896 - val_categorical_accuracy: 0.6675
# Epoch 6/25
# 16/16 [==============================] - 2s 98ms/step - loss: 2.5804 - categorical_accuracy: 0.6618 - val_loss: 2.4847 - val_categorical_accuracy: 0.6825
# Epoch 7/25
# 16/16 [==============================] - 1s 65ms/step - loss: 2.4789 - categorical_accuracy: 0.6744 - val_loss: 2.3906 - val_categorical_accuracy: 0.6712
# Epoch 8/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.4007 - categorical_accuracy: 0.6772 - val_loss: 2.3291 - val_categorical_accuracy: 0.6825
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.3211 - categorical_accuracy: 0.6810 - val_loss: 2.2537 - val_categorical_accuracy: 0.6850
# Epoch 10/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.2624 - categorical_accuracy: 0.6865 - val_loss: 2.1992 - val_categorical_accuracy: 0.6913
# Epoch 11/25
# 16/16 [==============================] - 2s 138ms/step - loss: 2.2106 - categorical_accuracy: 0.6907 - val_loss: 2.1557 - val_categorical_accuracy: 0.6950
# Epoch 12/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.1654 - categorical_accuracy: 0.6935 - val_loss: 2.1193 - val_categorical_accuracy: 0.6975
# Epoch 13/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.1311 - categorical_accuracy: 0.6962 - val_loss: 2.1065 - val_categorical_accuracy: 0.6925
# Epoch 14/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.0945 - categorical_accuracy: 0.6967 - val_loss: 2.0661 - val_categorical_accuracy: 0.6988
# Epoch 15/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0709 - categorical_accuracy: 0.7000 - val_loss: 2.0423 - val_categorical_accuracy: 0.7000
# Epoch 16/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.0481 - categorical_accuracy: 0.7017 - val_loss: 2.0196 - val_categorical_accuracy: 0.7025
# Epoch 17/25
# 16/16 [==============================] - 1s 68ms/step - loss: 2.0269 - categorical_accuracy: 0.7037 - val_loss: 2.0227 - val_categorical_accuracy: 0.7013
# Epoch 18/25
# 16/16 [==============================] - 1s 93ms/step - loss: 2.0038 - categorical_accuracy: 0.7056 - val_loss: 1.9916 - val_categorical_accuracy: 0.7063
# Epoch 19/25
# 16/16 [==============================] - 1s 78ms/step - loss: 1.9932 - categorical_accuracy: 0.7069 - val_loss: 1.9701 - val_categorical_accuracy: 0.7063
# Epoch 20/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9672 - categorical_accuracy: 0.7112 - val_loss: 1.9556 - val_categorical_accuracy: 0.7038
# Epoch 21/25
# 16/16 [==============================] - 1s 54ms/step - loss: 1.9536 - categorical_accuracy: 0.7122 - val_loss: 1.9441 - val_categorical_accuracy: 0.7038
# Epoch 22/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9370 - categorical_accuracy: 0.7154 - val_loss: 1.9409 - val_categorical_accuracy: 0.7025
# Epoch 23/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9298 - categorical_accuracy: 0.7146 - val_loss: 1.9170 - val_categorical_accuracy: 0.7125
# Epoch 24/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9117 - categorical_accuracy: 0.7198 - val_loss: 1.9257 - val_categorical_accuracy: 0.7138
# Epoch 25/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9006 - categorical_accuracy: 0.7188 - val_loss: 1.8960 - val_categorical_accuracy: 0.7163

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
